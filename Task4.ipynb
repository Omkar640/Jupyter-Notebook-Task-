# %%
data_list = [
    10,                 
    25.5,               
    "Python",           
    True,               
    [1, 2, 3],         
    (4, 5),             
    {"a": 1},           
    {1, 2, 3},          
    None,               
    3 + 4j              
]


for item in data_list:
    print(item, "=>", type(item))
# Out:
# 10 => <class 'int'>
# 25.5 => <class 'float'>
# Python => <class 'str'>
# True => <class 'bool'>
# [1, 2, 3] => <class 'list'>
# (4, 5) => <class 'tuple'>
# {'a': 1} => <class 'dict'>
# {1, 2, 3} => <class 'set'>
# None => <class 'NoneType'>
# (3+4j) => <class 'complex'>
