# %%
name = "Omkar"
print("Name:", name)

subjects = ["DS", "ML", "Python"]
print("Subjects:", subjects)

percentage = 85.75
print("Percentage:", percentage)

marks = (85, 90, 88)
print("Marks:", marks)
# Out:
# Name: Omkar
# Subjects: ['DS', 'ML', 'Python']
# Percentage: 85.75
# Marks: (85, 90, 88)
